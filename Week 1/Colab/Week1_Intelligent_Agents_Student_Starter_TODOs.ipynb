# %% [markdown]
# <a href="https://colab.research.google.com/github/DASatizabal/Artificial-Intelligence-Class/blob/main/Week%201/Colab/Week1_Intelligent_Agents_Student_Starter_TODOs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Week 1 In-Class Activity: Introduction to AI and Intelligent Agents
#
# ## Title
# **Design, Test, and Evaluate an Intelligent Agent Using Real-World-Style Data**
#
# ## Objective
# Students apply intelligent-agent concepts using PEAS, task-environment classification, rationality, a rule-based agent, data quality checks, visualization, model evaluation, and the bias-variance tradeoff.
#
# ## Activity Overview
# Teams of 3–4 use a **20,000-row dataset** covering eight intelligent-agent applications. The activity progresses from a simple rule-based weather agent to a supervised-learning comparison.
#
# **Environment → Percept → Rule/Model → Action → Evaluation → Reflection → Improvement**

# %% [markdown]
# ## Step 1: Group Formation (5 minutes)
# - Divide students into groups of 3–4.
# - Assign Agent Designer, Data Analyst, Safety/Ethics Reviewer, and Presenter.
# - Select one application: autonomous delivery robot, smart hospital assistant, cybersecurity monitoring agent, intelligent tutoring system, smart-home energy agent, autonomous vehicle, warehouse robot, or AI travel assistant.

# %% [markdown]
# ## Step 2: Hands-On Implementation
# - Load the dataset using `pd.read_csv("week1_intelligent_agents_large_dataset.csv")`.
# - Open `starter_script.py` and the Colab notebook.
# - Review attributes, data types, missing values, categorical variables, and target variables.
#
# ### Resources Provided
# - Dataset (.csv)
# - Student starter notebook with TODOs
# - Ready-to-run Google Colab notebook
# - Instructor EXECUTED notebook
# - starter_script.py

# %% [markdown]
# ## Notebook Setup — LECTURE MARKER

# %%
from pathlib import Path
import warnings
warnings.filterwarnings("ignore")
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import urllib.request

from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, classification_report

CANDIDATES=[
    Path.cwd()/"datasets", Path.cwd(),
    Path("/content/datasets"), Path("/content"),
    Path("/mnt/data/Week1_Hands_On_Intelligent_Agents_Activity/datasets")
]
FILENAME = "week1_intelligent_agents_large_dataset.csv"
GITHUB_RAW_URL = "https://raw.githubusercontent.com/DASatizabal/Artificial-Intelligence-Class/main/Week%201/week1_intelligent_agents_large_dataset.csv"

DATA_DIR=next((p for p in CANDIDATES if (p/FILENAME).exists()),None)

if DATA_DIR is None:
    DATA_DIR = CANDIDATES[0]
    DATA_DIR.mkdir(parents=True, exist_ok=True)
    urllib.request.urlretrieve(GITHUB_RAW_URL, DATA_DIR/FILENAME)

DATA_PATH=DATA_DIR/FILENAME
df=pd.read_csv(DATA_PATH)

print("Using dataset:",DATA_PATH)
print("Shape:",df.shape)
display(df.head())
# Out:
# Using dataset: /content/datasets/week1_intelligent_agents_large_dataset.csv
# Shape: (20000, 19)
#    episode_id                  application agent_architecture environment  \
# 0           1     Smart Hospital Assistant      Simple Reflex      Cloudy
# 1           2          AI Travel Assistant         Goal-Based       Windy
# 2           3              Warehouse Robot        Model-Based      Stormy
# 3           4     Smart Hospital Assistant           Learning       Sunny
# 4           5  Intelligent Tutoring System        Model-Based       Rainy
#
#        expected_action  sensor_confidence  risk_level  environment_volatility  \
# 0          Stay Inside             0.8421      0.1455                  0.2159
# 1  Use Wind Protection             1.0000      0.1116                  0.5386
# 2          Stay Inside             0.8080      0.5698                  0.7778
# 3           Go Outside             0.8048      0.1477                  0.3205
# ...

# %% [markdown]
# ### Dataset Exploration

# %%
# // TODO 1: Display df.info()
# // TODO 2: Count missing values by column.
# // TODO 3: Display environment counts.
# // TODO 4: Display application counts.

# %% [markdown]
# ## PEAS / Agent Design Worksheet
#
# | Component | Group Response |
# |---|---|
# | Agent | |
# | Performance Measure | |
# | Environment | |
# | Actuators | |
# | Sensors | |
# | Observable/Partially Observable | |
# | Deterministic/Stochastic | |
# | Episodic/Sequential | |
# | Static/Dynamic | |
# | Discrete/Continuous | |
# | Single/Multi-Agent | |
# | Recommended Agent Architecture | |
# | Rational Action Example | |
# | Irrational Action Example | |
# | Major Challenge | |
#
# Groups must justify why the selected architecture is appropriate.

# %% [markdown]
# ## Step 3: Group Task (20 minutes)
#
# ### Part A — Rule-Based Intelligent Agent
# 1. Implement `agent_action(environment)`.
# 2. Apply it to the dataset.
# 3. Compare output with `expected_action`.
# 4. Calculate rule-based accuracy.
# 5. Identify cases requiring a default or human-review action.
#
# ### Part B — Data Quality
# 1. Count missing values.
# 2. Inspect numeric descriptive statistics.
# 3. Visualize response-time distribution.
# 4. Explain how missing percepts could affect decisions.
# 5. Select a preprocessing strategy.
#
# ### Part C — Bias-Variance Model Comparison
# Compare:
# - Decision Tree with `max_depth=3`
# - Random Forest
#
# Evaluate:
# - train accuracy
# - test accuracy
# - test F1
# - generalization gap
#
# ### Part D — Visualization
# Create:
# - rule-based performance chart;
# - training vs test model comparison chart.

# %% [markdown]
# ### Part A — Build the Rule-Based Agent

# %%
# // TODO 5: Complete agent_action(environment).
def agent_action(environment):
    pass

# // TODO 6: Apply it to df["environment"].
# // TODO 7: Create df["rule_correct"].
# // TODO 8: Calculate rule_accuracy.

# %% [markdown]
# ### Part B — Data Quality Before Modeling

# %%
# // TODO 9: Display missing-value counts.
# // TODO 10: Display numeric descriptive statistics.
# // TODO 11: Create a histogram of response_time_ms with title and labels.

# %% [markdown]
# ### Part C — Train/Test Split and Bias-Variance Comparison

# %%
# // TODO 12: Define numeric features.
# // TODO 13: Create X and y.
# // TODO 14: Create a stratified 75/25 train/test split.
# // TODO 15: Build shallow Decision Tree pipeline.
# // TODO 16: Build Random Forest pipeline.
# // TODO 17: Fit both models.
# // TODO 18: Calculate train accuracy, test accuracy, test F1, and generalization gap.

# %% [markdown]
# ### Part D — Evaluation and Visualization

# %%
# // TODO 19: Plot training vs test accuracy.
# // TODO 20: Choose the better model using TEST evidence.
# // TODO 21: Print classification_report and confusion_matrix.
# // TODO 22: Create a rule-based accuracy visualization.

# %% [markdown]
# ## Step 4: Research, Discussion & Reflection (30 minutes)
# Discuss what worked, what did not, and why. Connect findings to PEAS, rationality, environment complexity, data quality, model reliability, and the bias-variance tradeoff.
#
# ### Required Reflection Questions
# 1. What key insights were revealed through your evaluation process?
# 2. Which model or technique provided the best results, and why?
# 3. What were the main challenges faced during the analysis?
# 4. How do your findings demonstrate the bias-variance tradeoff?
# 5. What steps could improve model performance and reliability?

# %% [markdown]
# ## Step 5: Wrap-Up (5 minutes)
# Review:
# - agents perceive and act;
# - PEAS defines the task;
# - rationality depends on expected performance and available information;
# - rule-based systems are transparent but inflexible;
# - data-driven models require preprocessing and unseen-data evaluation;
# - bias and variance are competing concerns.

# %% [markdown]
# ## Instructor Emphasizes
# - Even minor data flaws can lead to significant AI/ML errors.
# - Data quality, preprocessing, and evaluation are equally important as algorithm choice.
# - Accuracy alone does not establish safety, fairness, or reliability.
# - More complex AI is not automatically better AI.

# %% [markdown]
# ## Submission and Reminders
# Submit a **1–2-page APA-formatted paper** with:
# - PEAS specification;
# - environment classification;
# - code excerpts;
# - screenshots;
# - model results;
# - bias-variance interpretation;
# - reflection responses;
# - references and citations.
#
# Upload through **Canvas LMS** as Word or PDF.
#
# **Due: Sunday, 11:59 PM.**

# %% [markdown]
# ## Final Group Output Checklist
# - PEAS worksheet
# - environment classification
# - working rule-based agent
# - rule accuracy
# - missing-data analysis
# - at least two visualizations
# - Decision Tree vs Random Forest results
# - bias-variance explanation
# - five reflection responses
# - screenshots for the APA paper
